# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2

# %%
fnames = os.listdir('data/east/clean/')

# %%
def plot_localization(fnames, n_sample ,figsize):
    sample = np.random.choice(fnames,size =n_sample,replace = False)
    plt.figure(figsize = figsize)
    for i, img in enumerate(sample):
        clean = plt.imread('data/east/clean/{}'.format(img))
        mask = plt.imread('data/east/mask/{}'.format(img))
        plt.subplot(n_sample,2,2*i +1)
        plt.imshow(clean)
        plt.subplot(n_sample,2,2*i +2)
        plt.imshow(clean*(mask==0))
    plt.show()

# %%
plot_localization(fnames,8,(5,20))

# %%
def plot_repainted(fnames, n_sample ,figsize):
    sample = np.random.choice(fnames,size =n_sample,replace = False)
    plt.figure(figsize = figsize)
    for i, img in enumerate(sample):
        clean = plt.imread('data/east/clean/{}'.format(img))
        impainted = plt.imread('data/east/impainted/{}'.format(img))
        mask = plt.imread('data/east/mask/{}'.format(img))
        plt.subplot(n_sample,3,3*i +1)
        plt.imshow(clean)
        plt.subplot(n_sample,3,3*i +2)
        plt.imshow(impainted)
        plt.subplot(n_sample,3,3*i +3)
        plt.imshow(clean*(mask==0))
    plt.show()

# %%
plot_repainted(fnames,8,(15,50))
